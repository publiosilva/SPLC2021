# %%
import pandas as pd
import numpy as np

from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn.feature_selection import SelectFromModel

import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('./files/dataset.csv')

dataset.head()
# Out:
#    Feature Model  Number of Features  Number of Mandatory Features  \
# 0           RaaS                  32                             2
# 1  AvionFEatures                  10                             4
# 2      Bike Shop                  21                             3
# 3      Jetbrains                  33                            13
# 4         Ubuntu                  11                             3
#
#    Number of Top Features  Number of Leaf Features   Depth of Tree Max  \
# 0                      19                       28                   3
# 1                       5                        7                   3
# 2                       5                       15                   5
# 3                       3                       25                   4
# 4                       4                        7                   3
#
#    Cognitive Complexity of Feature Model  Feature Extensibility  \
# 0                                      3                     28
# 1                                      2                      7
# 2                                      5                     27
# 3                                      2                     28
# 4                                      3                      7
#
#    Flexibility of Configuration  Single Cylic Dependent Features  \
# 0                      0.531250                                0
# 1                      0.100000                                0
# 2                      0.095238                                9
# 3                      0.272727                                3
# 4                      0.090909                                0
#
#    Multiple Cyclic Dependent Features  \
# 0                                   0
# 1                                   0
# 2                                   3
# 3                                   0
# 4                                   0
#
#    Number of Features Referenced in Constraints Mean  Ratio of Variability  \
# 0                                                0.0              4.857143
# 1                                                0.0              2.200000
# 2                                                0.0              2.272727
# 3                                                2.0              3.400000
# 4                                                1.0              1.857143
#
#    Number of Valid Configurations  Number of Groups OR  Number of Groups XOR  \
# 0                     125829120.0                    3                     0
# 1                            12.0                    2                     0
# 2                            70.0                    1                     4
# 3                          4884.0                    0                     2
# 4                            12.0                    0                     3
#
#    Maintainability
# 0         moderate
# 1         verygood
# 2             good
# 3         moderate
# 4         verygood

# %%
# X = dataset.iloc[:, [1, 2, 4, 5, 6, 7, 14, 15]] # Correlation
# X = dataset.iloc[:, [1, 4, 5, 6, 7, 12]] # mutual_info_classif
X = dataset.iloc[:, [1, 2, 3, 4, 5, 6, 7, 14]] # Select From Model
# X = dataset.iloc[:, 1:-1]
y = dataset.iloc[:, -1]

# %%
scaler = StandardScaler()
clf = LogisticRegression(random_state=0,)
pipeline = make_pipeline(scaler, clf)
pipeline.fit(X, y)

scores = cross_val_score(pipeline, X, y, cv=10)

print(np.mean(scores), np.std(scores))
# Out:
# /home/publio/.local/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# /home/publio/.local/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# /home/publio/.local/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# /home/publio/.local/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# /home/publio/.local/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# /home/publio/.local/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# /home/publio/.local/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# /home/publio/.local/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# /home/publio/.local/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# 0.6461344537815126 0.044714174374741955
# /home/publio/.local/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# /home/publio/.local/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "

# %%
scaler = StandardScaler()
clf = LogisticRegression(random_state=0)
pipeline = make_pipeline(scaler, clf)
pipeline.fit(X, y)

model = SelectFromModel(clf, prefit=True)

print(X.columns[model.get_support()])

X_new = model.transform(X)

pipeline.fit(X_new, y)

scores = cross_val_score(pipeline, X_new, y, cv=5)
scores
# Out:
# Index(['Number of Features', 'Number of Mandatory Features',
#        ' Depth of Tree Max', 'Cognitive Complexity of Feature Model'],
#       dtype='object')
# array([0.5942029 , 0.62318841, 0.67647059, 0.60294118, 0.61764706])
