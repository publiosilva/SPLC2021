# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.tree import DecisionTreeClassifier, export_text, plot_tree
from sklearn.model_selection import cross_val_score
from sklearn.feature_selection import SelectFromModel

# %%
dataset = pd.read_csv('./files/dataset.csv')

dataset.head()
# Out:
#    Feature Model  Number of Features  Number of Mandatory Features  \
# 0           RaaS                  32                             2
# 1  AvionFEatures                  10                             4
# 2      Bike Shop                  21                             3
# 3      Jetbrains                  33                            13
# 4         Ubuntu                  11                             3
#
#    Number of Top Features  Number of Leaf Features   Depth of Tree Max  \
# 0                      19                       28                   3
# 1                       5                        7                   3
# 2                       5                       15                   5
# 3                       3                       25                   4
# 4                       4                        7                   3
#
#    Cognitive Complexity of Feature Model  Feature Extensibility  \
# 0                                      3                     28
# 1                                      2                      7
# 2                                      5                     27
# 3                                      2                     28
# 4                                      3                      7
#
#    Flexibility of Configuration  Single Cylic Dependent Features  \
# 0                      0.531250                                0
# 1                      0.100000                                0
# 2                      0.095238                                9
# 3                      0.272727                                3
# 4                      0.090909                                0
#
#    Multiple Cyclic Dependent Features  \
# 0                                   0
# 1                                   0
# 2                                   3
# 3                                   0
# 4                                   0
#
#    Number of Features Referenced in Constraints Mean  Ratio of Variability  \
# 0                                                0.0              4.857143
# 1                                                0.0              2.200000
# 2                                                0.0              2.272727
# 3                                                2.0              3.400000
# 4                                                1.0              1.857143
#
#    Number of Valid Configurations  Number of Groups OR  Number of Groups XOR  \
# 0                     125829120.0                    3                     0
# 1                            12.0                    2                     0
# 2                            70.0                    1                     4
# 3                          4884.0                    0                     2
# 4                            12.0                    0                     3
#
#    Maintainability
# 0         moderate
# 1         verygood
# 2             good
# 3         moderate
# 4         verygood

# %%
# X = dataset.iloc[:, [1, 2, 4, 5, 6, 7, 14, 15]] # Correlation
# X = dataset.iloc[:, [1, 4, 5, 6, 7, 12]] # mutual_info_classif
X = dataset.iloc[:, [1, 2, 3, 4, 5, 8]] # Select From Model
# X = dataset.iloc[:, 1:-1]
y = dataset.iloc[:, -1]

X
# Out:
#      Number of Features  Number of Mandatory Features  Number of Top Features  \
# 0                    32                             2                      19
# 1                    10                             4                       5
# 2                    21                             3                       5
# 3                    33                            13                       3
# 4                    11                             3                       4
# ..                  ...                           ...                     ...
# 337                  10                             2                       4
# 338                  17                             9                       3
# 339                  19                             4                       3
# 340                  10                             1                       4
# 341                  37                            18                      12
#
#      Number of Leaf Features   Depth of Tree Max  \
# 0                         28                   3
# 1                          7                   3
# 2                         15                   5
# 3                         25                   4
# 4                          7                   3
# ..                       ...                 ...
# 337                        7                   3
# 338                       12                   4
# 339                       12                   4
# 340                        7                   3
# 341                       25                   4
#
#      Cognitive Complexity of Feature Model  Feature Extensibility  \
# 0                                        3                     28
# 1                                        2                      7
# 2                                        5                     27
# 3                                        2                     28
# 4                                        3                      7
# ..                                     ...                    ...
# 337                                      2                      7
# 338                                      1                     12
# 339                                      4                     16
# 340                                      0                      7
# 341                                      6                     40
#
#      Flexibility of Configuration  Single Cylic Dependent Features  \
# 0                        0.531250                                0
# 1                        0.100000                                0
# 2                        0.095238                                9
# 3                        0.272727                                3
# 4                        0.090909                                0
# ..                            ...                              ...
# 337                      0.200000                                0
# 338                      0.294118                                0
# 339                      0.157895                                2
# 340                      0.800000                                0
# 341                      0.081081                               13
#
#      Multiple Cyclic Dependent Features  \
# 0                                     0
# 1                                     0
# 2                                     3
# 3                                     0
# 4                                     0
# ..                                  ...
# 337                                   0
# 338                                   0
# 339                                   2
# 340                                   0
# 341                                   2
#
#      Number of Features Referenced in Constraints Mean  Ratio of Variability  \
# 0                                                  0.0              4.857143
# 1                                                  0.0              2.200000
# 2                                                  0.0              2.272727
# 3                                                  2.0              3.400000
# 4                                                  1.0              1.857143
# ..                                                 ...                   ...
# 337                                                0.0              2.200000
# 338                                                0.0              2.833333
# 339                                                1.0              2.000000
# 340                                                0.0              3.000000
# 341                                               36.0              2.333333
#
#      Number of Valid Configurations  Number of Groups OR  Number of Groups XOR
# 0                       125829120.0                    3                     0
# 1                              12.0                    2                     0
# 2                              70.0                    1                     4
# 3                            4884.0                    0                     2
# 4                              12.0                    0                     3
# ..                              ...                  ...                   ...
# 337                            36.0                    1                     1
# 338                            96.0                    1                     0
# 339                           192.0                    2                     2
# 340                           160.0                    0                     0
# 341                          1296.0                    1                     5
#
# [342 rows x 15 columns]

# %%
scaler = StandardScaler()
clf = DecisionTreeClassifier(random_state=0, max_depth=5)
pipeline = make_pipeline(scaler, clf)
pipeline.fit(X, y)

scores = cross_val_score(pipeline, X, y, cv=10)

print("Scores:", scores)
print("Mean:", np.mean(scores), "| Standard Deviation:", np.std(scores))
# Out:
# Scores: [0.74285714 0.82857143 0.82352941 0.70588235 0.73529412 0.88235294
#  0.70588235 0.91176471 0.79411765 0.76470588]
# Mean: 0.7894957983193278 | Standard Deviation: 0.067814917788357

# %%
# plt.figure(figsize=(50, 20))

# plot_tree(clf, fontsize=10, feature_names=['NF', 'NM', 'NTop', 'NLeaf', 'DTMax', 'FoC'], class_names=['verybad', 'good', 'moderate', 'bad', 'verygood'])

# plt.show()

# %%
# feat_importances = pd.Series(clf.feature_importances_, index = X.columns) 
# feat_importances.nlargest(15).plot(kind = 'barh') 
# plt.show()

# %%
# scaler = MinMaxScaler()
# clf = DecisionTreeClassifier(random_state=0)
# pipeline = make_pipeline(scaler, clf)
# pipeline.fit(X, y)

# model = SelectFromModel(clf, prefit=True)

# print(np.array(X.columns[model.get_support()]))

# X_new = model.transform(X)

# pipeline.fit(X_new, y)

# scores = cross_val_score(pipeline, X_new, y, cv=10)
# print(np.mean(scores), np.std(scores))

# %%
# tree_text_rep = export_text(clf, feature_names=['NF', 'NM', 'NTop', 'NLeaf', 'DTMax', 'FoC'], max_depth=15)
tree_text_rep = export_text(clf)

print(tree_text_rep)
# Out:
# |--- feature_4 <= -0.48
# |   |--- feature_3 <= -0.07
# |   |   |--- feature_3 <= -0.18
# |   |   |   |--- class: verygood
# |   |   |--- feature_3 >  -0.18
# |   |   |   |--- feature_3 <= -0.13
# |   |   |   |   |--- feature_1 <= 0.74
# |   |   |   |   |   |--- class: good
# |   |   |   |   |--- feature_1 >  0.74
# |   |   |   |   |   |--- class: verygood
# |   |   |   |--- feature_3 >  -0.13
# |   |   |   |   |--- class: verygood
# |   |--- feature_3 >  -0.07
# |   |   |--- feature_3 <= 0.44
# |   |   |   |--- feature_0 <= 0.00
# |   |   |   |   |--- feature_3 <= -0.02
# |   |   |   |   |   |--- class: good
# |   |   |   |   |--- feature_3 >  -0.02
# |   |   |   |   |   |--- class: bad
# |   |   |   |--- feature_0 >  0.00
# |   |   |   |   |--- class: moderate
# |   |   |--- feature_3 >  0.44
# |   |   |   |--- feature_2 <= -0.79
# |   |   |   |   |--- class: verygood
# |   |   |   |--- feature_2 >  -0.79
# |   |   |   |   |--- feature_1 <= -0.14
# |   |   |   |   |   |--- class: bad
# |   |   |   |   |--- feature_1 >  -0.14
# |   |   |   |   |   |--- class: verybad
# |--- feature_4 >  -0.48
# |   |--- feature_0 <= 0.10
# |   |   |--- feature_0 <= -0.32
# |   |   |   |--- feature_5 <= 0.14
# |   |   |   |   |--- feature_2 <= -0.79
# |   |   |   |   |   |--- class: good
# |   |   |   |   |--- feature_2 >  -0.79
# |   |   |   |   |   |--- class: good
# |   |   |   |--- feature_5 >  0.14
# |   |   |   |   |--- feature_2 <= -0.50
# |   |   |   |   |   |--- class: verygood
# |   |   |   |   |--- feature_2 >  -0.50
# |   |   |   |   |   |--- class: good
# |   |   |--- feature_0 >  -0.32
# |   |   |   |--- feature_5 <= 0.83
# |   |   |   |   |--- feature_4 <= 1.27
# |   |   |   |   |   |--- class: moderate
# |   |   |   |   |--- feature_4 >  1.27
# |   |   |   |   |   |--- class: good
# |   |   |   |--- feature_5 >  0.83
# |   |   |   |   |--- feature_0 <= -0.09
# |   |   |   |   |   |--- class: verygood
# |   |   |   |   |--- feature_0 >  -0.09
# |   |   |   |   |   |--- class: moderate
# |   |--- feature_0 >  0.10
# |   |   |--- feature_4 <= 1.27
# |   |   |   |--- feature_5 <= 2.05
# |   |   |   |   |--- feature_3 <= 0.03
# |   |   |   |   |   |--- class: moderate
# |   |   |   |   |--- feature_3 >  0.03
# |   |   |   |   |   |--- class: bad
# |   |   |   |--- feature_5 >  2.05
# |   |   |   |   |--- class: verygood
# |   |   |--- feature_4 >  1.27
# |   |   |   |--- feature_1 <= 3.63
# |   |   |   |   |--- feature_3 <= 0.31
# |   |   |   |   |   |--- class: verybad
# |   |   |   |   |--- feature_3 >  0.31
# |   |   |   |   |   |--- class: verybad
# |   |   |   |--- feature_1 >  3.63
# |   |   |   |   |--- class: bad

# %%
# import re
# import json

# prog1 = re.compile('feature.*')
# prog2 = re.compile('class.*')

# rows = tree_text_rep.split("\n")

# features = {
#     'feature_0': 'NF',
#     'feature_1': 'NM',
#     'feature_2': 'NTop',
#     'feature_3': 'NLeaf',
#     'feature_4': 'DTMax',
#     'feature_5': 'FoC'
# }

# def generate_tree(rows, level = 1):
#     left = []
#     right = []
#     reading_left = True

#     for index, row in enumerate(rows):
#         if index > 0 and row.count("|") == level:
#             reading_left = False

#         if reading_left:
#             left.append(row)
#         else:
#             right.append(row)
            
#     rule = None
#     label = None
#     leftNode = None
#     rightNode = None
    
#     left = list(filter(lambda x: x != '', left))
#     right = list(filter(lambda x: x != '', right))
    
#     if len(prog1.findall(left[0])) > 0:
#         temp_x = [[0, 0, 0, 0, 0, 0]]
#         r = prog1.findall(left[0])[0]
#         parts_r = r.split(' <= ')
#         index_r = int(parts_r[0].replace('feature_', ''))
#         value_r = float(parts_r[1])
#         temp_x[0][index_r] = value_r
#         new_x = scaler.inverse_transform(temp_x)
#         rule = {
#             'feature': features["feature_" + str(index_r)],
#             'comparator': '<=',
#             'threshold': new_x[0][index_r]
#         }
    
#     if len(left) > 1:
#         leftNode = generate_tree(left[1:], level + 1)
#     else:
#         a = prog2.findall(left[0])
#         if len(a) > 0:
#             label = a[0].replace("class: ", "")
    
#     if len(right) > 1:
#         rightNode = generate_tree(right[1:], level + 1)
    
#     return {
#         'rule': rule,
#         'left': leftNode,
#         'right': rightNode,
#         'label': label
#     }

# a = generate_tree(rows)
# json.dumps(a)
# Out:
# '{"rule": {"feature": "DTMax", "comparator": "<=", "threshold": 3.496507947334723}, "left": {"rule": {"feature": "NLeaf", "comparator": "<=", "threshold": 19.577809855770962}, "left": {"rule": {"feature": "NLeaf", "comparator": "<=", "threshold": 17.44862049796409}, "left": {"rule": null, "left": null, "right": null, "label": "verygood"}, "right": {"rule": {"feature": "NLeaf", "comparator": "<=", "threshold": 18.416433842421757}, "left": {"rule": {"feature": "NM", "comparator": "<=", "threshold": 16.039646136173833}, "left": {"rule": null, "left": null, "right": null, "label": "good"}, "right": {"rule": null, "left": null, "right": null, "label": "verygood"}, "label": null}, "right": {"rule": null, "left": null, "right": null, "label": "verygood"}, "label": null}, "label": null}, "right": {"rule": {"feature": "NLeaf", "comparator": "<=", "threshold": 29.449505969239183}, "left": {"rule": {"feature": "NF", "comparator": "<=", "threshold": 29.985380116959064}, "left": {"rule": {"feature": "NLeaf", "comparator": "<=", "threshold": 20.54562320022863}, "left": {"rule": null, "left": null, "right": null, "label": "good"}, "right": {"rule": null, "left": null, "right": null, "label": "bad"}, "label": null}, "right": {"rule": null, "left": null, "right": null, "label": "moderate"}, "label": null}, "right": {"rule": {"feature": "NTop", "comparator": "<=", "threshold": 2.503682288694361}, "left": {"rule": null, "left": null, "right": null, "label": "verygood"}, "right": {"rule": {"feature": "NM", "comparator": "<=", "threshold": 7.984596740161202}, "left": {"rule": null, "left": null, "right": null, "label": "bad"}, "right": {"rule": null, "left": null, "right": null, "label": "verybad"}, "label": null}, "label": null}, "label": null}, "label": null}, "right": {"rule": {"feature": "NF", "comparator": "<=", "threshold": 32.61043331553214}, "left": {"rule": {"feature": "NF", "comparator": "<=", "threshold": 21.58520988152522}, "left": {"rule": {"feature": "FoC", "comparator": "<=", "threshold": 0.2701833948084222}, "left": {"rule": {"feature": "NTop", "comparator": "<=", "threshold": 2.503682288694361}, "left": {"rule": null, "left": null, "right": null, "label": "good"}, "right": {"rule": null, "left": null, "right": null, "label": "good"}, "label": null}, "right": {"rule": {"feature": "NTop", "comparator": "<=", "threshold": 3.4887470255634603}, "left": {"rule": null, "left": null, "right": null, "label": "verygood"}, "right": {"rule": null, "left": null, "right": null, "label": "good"}, "label": null}, "label": null}, "right": {"rule": {"feature": "FoC", "comparator": "<=", "threshold": 0.40030648121534823}, "left": {"rule": {"feature": "DTMax", "comparator": "<=", "threshold": 6.504792508251928}, "left": {"rule": null, "left": null, "right": null, "label": "moderate"}, "right": {"rule": null, "left": null, "right": null, "label": "good"}, "label": null}, "right": {"rule": {"feature": "NF", "comparator": "<=", "threshold": 27.622832238243294}, "left": {"rule": null, "left": null, "right": null, "label": "verygood"}, "right": {"rule": null, "left": null, "right": null, "label": "moderate"}, "label": null}, "label": null}, "label": null}, "right": {"rule": {"feature": "DTMax", "comparator": "<=", "threshold": 6.504792508251928}, "left": {"rule": {"feature": "FoC", "comparator": "<=", "threshold": 0.6303791847174494}, "left": {"rule": {"feature": "NLeaf", "comparator": "<=", "threshold": 21.5134365446863}, "left": {"rule": null, "left": null, "right": null, "label": "moderate"}, "right": {"rule": null, "left": null, "right": null, "label": "bad"}, "label": null}, "right": {"rule": null, "left": null, "right": null, "label": "verygood"}, "label": null}, "right": {"rule": {"feature": "NM", "comparator": "<=", "threshold": 42.493160629897126}, "left": {"rule": {"feature": "NLeaf", "comparator": "<=", "threshold": 26.933191273649243}, "left": {"rule": null, "left": null, "right": null, "label": "verybad"}, "right": {"rule": null, "left": null ...
