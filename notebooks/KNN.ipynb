# %%
import pandas as pd

from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score

# %%
dataset = pd.read_csv('./files/dataset.csv')

dataset.head()
# Out:
#    Feature Model  Number of Features  Number of Mandatory Features  \
# 0           RaaS                  32                             2
# 1  AvionFEatures                  10                             4
# 2      Bike Shop                  21                             3
# 3      Jetbrains                  33                            13
# 4         Ubuntu                  11                             3
#
#    Number of Top Features  Number of Leaf Features   Depth of Tree Max  \
# 0                      19                       28                   3
# 1                       5                        7                   3
# 2                       5                       15                   5
# 3                       3                       25                   4
# 4                       4                        7                   3
#
#    Cognitive Complexity of Feature Model  Feature Extensibility  \
# 0                                      3                     28
# 1                                      2                      7
# 2                                      5                     27
# 3                                      2                     28
# 4                                      3                      7
#
#    Flexibility of Configuration  Single Cylic Dependent Features  \
# 0                      0.531250                                0
# 1                      0.100000                                0
# 2                      0.095238                                9
# 3                      0.272727                                3
# 4                      0.090909                                0
#
#    Multiple Cyclic Dependent Features  \
# 0                                   0
# 1                                   0
# 2                                   3
# 3                                   0
# 4                                   0
#
#    Number of Features Referenced in Constraints Mean  Ratio of Variability  \
# 0                                                0.0              4.857143
# 1                                                0.0              2.200000
# 2                                                0.0              2.272727
# 3                                                2.0              3.400000
# 4                                                1.0              1.857143
#
#    Number of Valid Configurations  Number of Groups OR  Number of Groups XOR  \
# 0                     125829120.0                    3                     0
# 1                            12.0                    2                     0
# 2                            70.0                    1                     4
# 3                          4884.0                    0                     2
# 4                            12.0                    0                     3
#
#    Maintainability
# 0         moderate
# 1         verygood
# 2             good
# 3         moderate
# 4         verygood

# %%
maintainability_categories = {
    'verybad': 1,
    'bad': 2,
    'moderate': 3,
    'good': 4,
    'verygood': 5
}

X = dataset.iloc[:, 1:-1]
y = [maintainability_categories[i] for i in dataset.iloc[:, -1]]

# %%
clf = make_pipeline(StandardScaler(), KNeighborsClassifier(n_neighbors=3))
clf.fit(X, y)

scores = cross_val_score(clf, X, y, cv=5)
scores
# Out:
# array([0.72058824, 0.63235294, 0.63235294, 0.61764706, 0.70588235])
